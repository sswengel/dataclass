# %% [markdown]
# <h1>Data Report On Instagram Likes</h1>
#
# <h4>Sophia Swengel</h4>
#
# September 15, 2023
#
# <hr/>
#
# <p>Instagram is one of the social media posts I use the most to connect with friends and the wider world. I follow a variety of accounts, the general majority of which are people I know personally. Because of this, I hypothesize that <b>there is a positive relationship between the number of "likes" I grant Instagram posts and the ownership of the account of the post I liked by an individual as opposed to a group or organization.</b></p>
#
# <p>The data included in the liked_posts.json file is appropriate for testing the hypothesis because it measures the timestamps of "likes" I grant to Instagram posts as well as the names of the accounts that posted each post I "liked". I can pull from this data which accounts I have granted the most likes to.</p>

# %% [markdown]
# <p>This data was collected by Instagram owner Meta in order to generate a curated Instagram experience through algorithms generating relevant advertising and recommended posts, effectively tracking the user.</p>
# <p>The data may be <b>reliable</b> because it is what it is: every time I "like" a post, Meta's data gets another tick. It is all the "likes" that I have given to Instagram posts, and the data is an accurate reflection of my "liking" habits.</p>
# <p>The data may be <b>unreliable</b> because of Facebook-Instagram cross posting and user like fatigue. When people I follow post the same post on Facebook and Instagram, I often like whichever one I see first on either platform. Hence, many posts that I viewed and gave a like to via Facebook friendship that were also posted to Intagram will not be represented in the Instagram like data. Also, I am often quite picky with what I give "likes" to on Instagram and am sometimes even disinterested in 'liking' posts. Hence, posts that I liked but didn't like enough to 'like' will not be represented.</p>

# %% [markdown]
# <h3>Process</h3>
#
# In order to test our hypothesis, we can first load the Instagram likes data for my account, which I downloaded from Instagram itself.

# %%
import pandas as pd
import json

# %%
with open(r'/Users/sophiaswengel/Downloads/sophia_swengel_20230830/likes/liked_posts.json') as l:
    likes_data = json.load(l)

# %% [markdown]
# We can load up the data and see the many values it defines so we can figure out what list elements to examine. The list elements are stored within 'likes_media_likes'; knowing this allows us to access the list elements. Within 'likes_media_likes' is the 'title' value (the name of the Instagram account) and the 'string_list_data' value, which contains within it the values for 'href' (the link to the liked Instagram post that the data represents), 'value' (the emoticon used; in this case it is always a heart since that is how Instagram represents hearts), and 'timestamp' (the timestamp of the like in seconds since 1970).

# %%
likes_data
# Out:
# {'likes_media_likes': [{'title': 'fruits_magazine_archives',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4OAKpdlsBm/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572391466}]},
#   {'title': 'michaelpilmer',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4NwMhlBht_/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572383890}]},
#   {'title': 'j0cko_h0mo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4MOhGQH8jO/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572348184}]},
#   {'title': 'fruits_magazine_archives',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4LhueTltza/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572311081}]},
#   {'title': 'joshfreese',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4Kw13LhoBe/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572283094}]},
#   {'title': 'michaelpilmer',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4K2Npnh0I3/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572283065}]},
#   {'title': 'fruits_magazine_archives',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4I6sN_F1Wi/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572277593}]},
#   {'title': 'michaelpilmer',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4KXqrXBH6z/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572277582}]},
#   {'title': 'j0cko_h0mo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4I503gHXXt/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572227450}]},
#   {'title': 'michaelpilmer',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4I_sg0BA75/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572227429}]},
#   {'title': 'ropesnek',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4GsVifABEW/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572145563}]},
#   {'title': 'neozeiss',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4B3absHtCE/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572107373}]},
#   {'title': 'neozeiss',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4B3VXpnTrq/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572107365}]},
#   {'title': 'neozeiss',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4B3c2xHJzw/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572107362}]},
#   {'title': 'neozeiss',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4B3MUGHkc8/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572107351}]},
#   {'title': 'neozeiss',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4B3PgWnZl6/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572107348}]},
#   {'title': 'neozeiss',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4B3W-WHwyr/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572107337}]},
#   {'title': 'neozeiss',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4B3SvRnqnu/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1572107325}]},
#   {'title': 'joshfreese',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4AML1qpDV8/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1571948250}]},
#   {'title': 'joshfreese',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B4AiGn7pazO/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1571948245}]},
#   {'title': 'doog_schloog',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B3jZLKlgpIe/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1571363865}]},
#   {'title': 'tacotontoskent',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwDUny2OTxv/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693314745}]},
#   {'title': 'spudbyro',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwAg8TkuLEx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693314717}]},
#   {'title': 'inspirobot.me',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cwhlz0TNAyp/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693312231}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwhuFDUO2nD/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693312229}]},
#   {'title': 'no_new_tale_to_tell',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwgqxrrMga8/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693274465}]},
#   {'title': 'no_new_tale_to_tell',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cwgm_fps-Iu/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693274456}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwgGumHPckP/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693262912}]},
#   {'title': 'rocco.degrassi',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwDldpuPGSB/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693260606}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CwgLfkmqt7Y/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693257422}]},
#   {'title': 'missy_wallick',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwG2naIsPoe/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693256931}]},
#   {'title': 'blackgladiatorkills',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwfYm4ju0QC/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693230769}]},
#   {'title': 'tacotontoskent',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwfTSxvuhMF/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693230759}]},
#   {'title': '__addie.d__',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwdqaLhvO0l/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693183591}]},
#   {'title': 'thevaultoftheatomicspaceage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwYB4EtoR7H/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693113163}]},
#   {'title': 'twentisty',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CuJKeUlAN-n/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693109094}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwbGfHFSAIG/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693088037}]},
#   {'title': 'kentwired',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwaaPH8MFU-/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693066328}]},
#   {'title': 'inkyhack',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwXmEADLYZj/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1693009098}]},
#   {'title': 'folkartwork',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv7eNB_Ix2X/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692993588}]},
#   {'title': 'bjork',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwXbiDVNoUE/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692965308}]},
#   {'title': 'obviousplant',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwVd6L5Rerh/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692911522}]},
#   {'title': 'plasticdeervintage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwVdYmBujOg/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692908189}]},
#   {'title': 'skidrowgarage',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CwS0iO-suEz/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692888446}]},
#   {'title': 'skidrowgarage',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CwVCREesIyS/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692888409}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CwVIZfrvyPU/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692888068}]},
#   {'title': 'obviousplant',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwS85L7v_Y-/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692816145}]},
#   {'title': 'kentwired',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwSWT4oO6kI/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692813040}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwSbn14pONE/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692797285}]},
#   {'title': 'martiancolors',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwQ-kZeub9k/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692748330}]},
#   {'title': 'lilynoise',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwOou2TJ8Ou/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692738676}]},
#   {'title': 'shrimp_devo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwQC9ejKw74/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692715663}]},
#   {'title': 'kentwired',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwN3qR4s56w/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692642736}]},
#   {'title': 'obviousplant',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwNySRsxB1f/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692641480}]},
#   {'title': 'kentwired',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwNrh7QOAaJ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692637411}]},
#   {'title': 'kentstate_sds',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwNoM6ygoat/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692637382}]},
#   {'title': 'josh2hager',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwNPtFdM7N8/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692623646}]},
#   {'title': 'shout4shoutsake',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CwNBi7Pg-B1/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692615644}]},
#   {'title': 'jmothersbaugh',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwLb4duxrcy/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692573998}]},
#   {'title': 'winnerjeff',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CwLjfxcABIU/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692573661}]},
#   {'title': 'averyvhall',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwIl-elLAlF/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692467237}]},
#   {'title': 'renprovo',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CwIZr6Noonv/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692460794}]},
#   {'title': 'shout4shoutsake',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwEk938gweT/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692354973}]},
#   {'title': 'cornkisser',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CaYLhOkgUNT/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692305059}]},
#   {'title': 'gerald_casale',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CwDaOvtrf_A/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692298891}]},
#   {'title': 'winnerjeff',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Cv_RdJCAaWg/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692155042}]},
#   {'title': 'shrimp_devo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv-tgVmPZrs/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692135384}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv-aGg0PGPm/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692133126}]},
#   {'title': 'renprovo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv9bNNbOOCa/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692106169}]},
#   {'title': 'zuggyandkathy',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv9xx8HuaBz/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692104409}]},
#   {'title': 'gerald_casale',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv9wpOhopbx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692104380}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv7lCaUSA0D/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1692029545}]},
#   {'title': 'averyvhall',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv6Fga6LB06/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691978765}]},
#   {'title': 'flowfestivalhelsinki',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv2fQ0kpoyX/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691876175}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cv1YES3Mv9x/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691836571}]},
#   {'title': 'worldmicrophoneldn',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CvsAhBGMLf8/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691791287}]},
#   {'title': 'weintendtocausehavoc',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CvxkQWFApfc/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691695497}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvxGZZHuxui/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691683039}]},
#   {'title': 'devomonkie',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvw7OkJo9US/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691672431}]},
#   {'title': 'sciencesetfree',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtwOXtzgvf1/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691632401}]},
#   {'title': 'kentwired',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvvgna7MOyV/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691629473}]},
#   {'title': 'kentstateschoolofart',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvusO0mMFt-/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691597567}]},
#   {'title': 'darrinzwengel',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvtwJwxuwta/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691577601}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvsrxHQpwbO/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691552947}]},
#   {'title': 'trip.thompson',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvs5WiMuihw/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691536367}]},
#   {'title': 'annemarie_creates',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvsUujrNSrD/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691520587}]},
#   {'title': 'josh2hager',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvrqFZiOb3Y/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691494759}]},
#   {'title': 'krk_ryden',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvpFus1LmL9/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691408492}]},
#   {'title': 'reverendbwp',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvn_HuNtmAi/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691372627}]},
#   {'title': 'catatonicyouth',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvnGm12yL2T/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691362944}]},
#   {'title': 'winnerjeff',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvnWpm6PuZ5/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691352448}]},
#   {'title': 'masonst_518',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvk9hUCADrL/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691270242}]},
#   {'title': 'joanng___',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvkW4QAsroS/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691251912}]},
#   {'title': 'krk_ryden',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvj5HQyLUCe/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691237512}]},
#   {'title': 'gishya_33.3',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvjX-hvOrDW/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691236125}]},
#   {'title': 'american_daydream_miscellanea',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvh0EsCOWeX/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691169540}]},
#   {'title': 'melt_banana',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvgoY-OvIlJ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691150190}]},
#   {'title': 'j0cko_h0mo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvg8Q-zuOfr/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691150182}]},
#   {'title': 'dasharez0neadmin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvdTOiSOeQr/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691015396}]},
#   {'title': 'martiancolors',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvc-EANOp7t/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1691002972}]},
#   {'title': 'studyabroadkent',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvctUBGOFkw/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690994743}]},
#   {'title': 'plasticdeervintage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cvcol-jO1rw/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690991518}]},
#   {'title': 'no_new_tale_to_tell',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvbTf93MG01/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690946471}]},
#   {'title': 'kylegordonisgreat',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CpgG9PCJ8ep/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690934606}]},
#   {'title': 'studyabroadkent',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvZrS8auAa4/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690896036}]},
#   {'title': 'shout4shoutsake',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvYUtp_AViQ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690848129}]},
#   {'title': 'wickpoetry',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvXKOf1udnQ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690819250}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CvXdIPBMOrG/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690816821}]},
#   {'title': 'trip.thompson',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvVsggkOmzF/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690802361}]},
#   {'title': 'natalieknepp',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CvVr80igs-5/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690763204}]},
#   {'title': 'art4mstudio',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvVe_I4vC54/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690753810}]},
#   {'title': 'tr1nd1n',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvVA3PAOiAr/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690740455}]},
#   {'title': 'ems_noel21',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvT4EQQsW3a/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690714122}]},
#   {'title': 'terriblemap',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvSfSrTNPeT/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690653462}]},
#   {'title': 'peachesrecords',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Cs35I1YI8Lv/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690652932}]},
#   {'title': 'plasticdeervintage',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CvSM_SXAiJu/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690641150}]},
#   {'title': 'ems_noel21',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvQ6MYsukv6/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690598801}]},
#   {'title': 'shout4shoutsake',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvQzAk_gypx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690595170}]},
#   {'title': 'rockyearbooks',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvP6pznL0vx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690565496}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvPyh61uhD3/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690560324}]},
#   {'title': 'josh2hager',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvOhK7osK76/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690539029}]},
#   {'title': 'sstark2624',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvOCPbdONBR/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690506463}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CvNnvDULKhY/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690489593}]},
#   {'title': 'plasticdeervintage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvNotuFuolw/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690489363}]},
#   {'title': 'everythingisterrible666',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CvKvtMqKmPp/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690398182}]},
#   {'title': 'krk_ryden',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvKDhsDr62g/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690367336}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvIsExgu4RJ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690321296}]},
#   {'title': 'thevaultoftheatomicspaceage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvCCN-LoSpQ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690302297}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvGFv_mu7PY/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690234370}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvF5etRuWdK/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690231362}]},
#   {'title': 'obviousplant',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvFh4WexUJF/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690224469}]},
#   {'title': 'tomo7701',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvFqqZSOGdq/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690224465}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvFnbu0OHF9/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690218179}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CvFekkQx2GI/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690215290}]},
#   {'title': 'darrinzwengel',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvEdX3LuvmL/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690197907}]},
#   {'title': 'thevaultoftheatomicspaceage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CvCCF7cItpx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690125652}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Cu_V29OMT7r/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1690021864}]},
#   {'title': 'sumerianrecord',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Cs2C_6Ogt6U/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689959953}]},
#   {'title': 'collectedsearching',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cu9e7Dlukdd/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689945673}]},
#   {'title': 'darrinzwengel',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cu8UVwDsCeP/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689906259}]},
#   {'title': 'rach_prutz',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cu7UUiaOuwt/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689880015}]},
#   {'title': 'toddcamp',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cu4xXF0rMSP/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689798355}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cu28PzuIqht/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689737529}]},
#   {'title': 'dissociative_dreams',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cuo_F-0RN-h/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689725255}]},
#   {'title': 'evolvedspudboy',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cu2VQ1ApBcJ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689712808}]},
#   {'title': 'alternativetentacles',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuxFt6CpCil/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689530990}]},
#   {'title': 'themuseumofmodernart',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CupH55mMCfR/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689418765}]},
#   {'title': 'ems_noel21',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CusxjGcr04F/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689418264}]},
#   {'title': 'krk_ryden',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CutOTn5so9l/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689414839}]},
#   {'title': 'bradleyjmarks',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CurcUuKLRBp/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689362337}]},
#   {'title': 'rockyearbooks',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Curza3XrM-n/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689356173}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Curw4Qmuh7v/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689356157}]},
#   {'title': 'gerald_casale',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Curvn1eOnmn/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689350125}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuquFcjumhi/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689332155}]},
#   {'title': 'alternativetentacles',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuptvaLpH3s/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689281994}]},
#   {'title': 'fightmilkband',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cupq8D3SNg6/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689281253}]},
#   {'title': 'obeygiant',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cumo3n3L_11/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689281118}]},
#   {'title': 'physic.fun',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CsFkg5pAih-/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689278232}]},
#   {'title': 'davide.adler',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Cun-xJTte9j/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689247214}]},
#   {'title': 'wickpoetry',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cunc6iuMmgY/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689208447}]},
#   {'title': 'bjork',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CuiHzazxOr2/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1689033569}]},
#   {'title': 'katigiblin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CugKpBOLzJF/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688986293}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/BvXLr0Bl7h7/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688937926}]},
#   {'title': 'tr1nd1n',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuclkkGONdv/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688847124}]},
#   {'title': 'shrimp_devo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cuceu-OOTR3/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688847103}]},
#   {'title': 'artoluminescent',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuE-l6gAzcf/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688832939}]},
#   {'title': 'yoshi_mae',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CucMwalKvAQ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688832392}]},
#   {'title': 'yoshi_mae',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CucNVnZKRa5/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688832388}]},
#   {'title': 'yoshi_mae',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CucMWDmqlit/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688832327}]},
#   {'title': 'bjork',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Cub1nkwppb9/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688817041}]},
#   {'title': 'skidrowgarage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cuavgpqtq3h/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688790974}]},
#   {'title': 'spudbyro',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuaKdpUxxbb/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688764670}]},
#   {'title': 'katigiblin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuaG2Dzv6n_/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688761290}]},
#   {'title': 'studyabroadkent',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuZoEaTOUan/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688742251}]},
#   {'title': 'criterioncollection',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuZX7lJO8TG/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688735438}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuX3QzgtlQd/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688730515}]},
#   {'title': 'fitasimples',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Ctm4xATr1eI/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688668718}]},
#   {'title': 'criterioncollection',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuUybBXs-EA/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688666299}]},
#   {'title': 'thevaultoftheatomicspaceage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuV3At6oSM6/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688665254}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuXUmRrM0nN/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688665232}]},
#   {'title': 'markgrud',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuVAVLHPg-f/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688645649}]},
#   {'title': 'riddlerzone',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CuO2T8cKpec/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688641304}]},
#   {'title': 'katigiblin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuV2QXhLIVZ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688641075}]},
#   {'title': 'detention.live',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CuVVpNqpNeu/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688600897}]},
#   {'title': 'no_new_tale_to_tell',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuSyXtbsk6P/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688512740}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuRmg7XO2_Z/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688473966}]},
#   {'title': 'jay.hellion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuQ3mHUubJE/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688471932}]},
#   {'title': 'arewenot.art',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuQeQJaN6y3/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688437509}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuLJIOEvxYU/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688256083}]},
#   {'title': 'art4mstudio',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuJC7ezOsSk/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688186946}]},
#   {'title': 'plasticdeervintage',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CuI2E9oA_Md/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688186906}]},
#   {'title': 'odpeacock',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuH2kwmA8VS/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688151849}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuH_xgByQOk/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1688151846}]},
#   {'title': 'samcahnruns',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Ct68wCqMLEy/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687997207}]},
#   {'title': 'annemarie_creates',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuBPBQKuonx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687949135}]},
#   {'title': 'ems_noel21',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuA3kATLibh/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687912275}]},
#   {'title': 'katigiblin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CuAfQLSuEU1/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687899760}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct_6VYyNbLY/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687884990}]},
#   {'title': 'jennyholzerstudio',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct9UF7lLgVm/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687792294}]},
#   {'title': 'odpeacock',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct9RsU7gxsn/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687792285}]},
#   {'title': 'devomonkie',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct8Pqmhr9jG/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687789646}]},
#   {'title': 'humour_hell',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtMsQCmLUJJ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687698892}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct5oeosLnHV/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687694416}]},
#   {'title': 'krk_ryden',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct6GMu7ueXo/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687694409}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Ct6IajYLnAm/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687694387}]},
#   {'title': 'thevaultoftheatomicspaceage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct3UEv7IJCi/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687647158}]},
#   {'title': 'darrinzwengel',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct4VqiBucwK/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687625618}]},
#   {'title': 'rockyearbooks',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct2hKybp8A0/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687573368}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct2cL7lvIXm/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687573343}]},
#   {'title': 'midcenturymoderation',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtzSmjUrWGc/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687555354}]},
#   {'title': 'joshfreese',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ct2JpI_OvQC/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687552813}]},
#   {'title': 'sanspoint_',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtzcUCSOPtI/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687461090}]},
#   {'title': 'owntheassmaskv2_',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ctj3j9yOa6T/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687461015}]},
#   {'title': 'marinadifranco',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtzXmIbx-wn/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687458410}]},
#   {'title': 'kentstate_sds',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cty4v1xADp6/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687451853}]},
#   {'title': 'martiancolors',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtxysfgrQFP/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687405765}]},
#   {'title': 'balletcomposer',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtunREjP9NX/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687350331}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtuVQlhu0Xs/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687293901}]},
#   {'title': 'no_new_tale_to_tell',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ctt0mj6Lri6/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687276653}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CttkzXPRQa7/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687264482}]},
#   {'title': 'dasharez0neadmin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ctp2ijHNCIf/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687142277}]},
#   {'title': 'maumausavannahcat',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ctpx5XdpYDl/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687139893}]},
#   {'title': 'metrosea',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ctph8ckpXW0/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687131171}]},
#   {'title': 'robinreneemusic',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtpQTLwPmg_/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687119661}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtpKe-oPFV6/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687116212}]},
#   {'title': 'rockyearbooks',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtnTxHfL8J0/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687055407}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtmkxF1vk_t/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687031791}]},
#   {'title': 'alternativetentacles',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ctmgjwvv4if/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687031785}]},
#   {'title': 'jello_biafra_gsm',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtmTVE0xLkT/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687020370}]},
#   {'title': 'jello_biafra_gsm',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtmTX4TRS3N/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687020368}]},
#   {'title': 'jello_biafra_gsm',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtmSw_uxkiT/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687020362}]},
#   {'title': 'plasticdeervintage',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Ctl9Wj8gPZx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687018667}]},
#   {'title': 'inspirobot.me',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtlSGHXtfvk/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1687002237}]},
#   {'title': 'devotedtonothing',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CthucUXsG11/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686866394}]},
#   {'title': 'obviousplant',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CthH7jxxFO3/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686848099}]},
#   {'title': 'rockyearbooks',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cte56yQJ3hw/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686773900}]},
#   {'title': 'joanng___',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CteYYS-ujcZ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686757692}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtdBl2CtH4D/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686712272}]},
#   {'title': 'catatonicyouth',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjzAWqpNaEg/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686701723}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ctbi8PyLTYP/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686661739}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtbgbyJLuhp/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686661738}]},
#   {'title': 'dana__katharine',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ctatn3huoEx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686651141}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtaZ78PN-uq/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686623147}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtZtWTbMRmV/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686601796}]},
#   {'title': 'inferiorbrainpower',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtZh6zhsGgP/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686594577}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtXgyz-vdMi/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686523909}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtXOvsQSEk3/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686515539}]},
#   {'title': 'natalieknepp',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtSC1IhAM4j/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686341732}]},
#   {'title': 'joshfreese',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtRhA_OLWh0/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686324748}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtROAX4oGGZ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686313951}]},
#   {'title': 'annemarie_creates',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtQXmGLMzS9/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686309306}]},
#   {'title': 'autoluminescentt',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtP-JNlLuvJ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686272123}]},
#   {'title': 'alternativetentacles',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtPgjauSfoH/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686257373}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtOvNqeO2tk/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686232014}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/B2aKdsMldJY/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686190227}]},
#   {'title': 'kentwired',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtNTPDYOgBR/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686183698}]},
#   {'title': 'alternativetentacles',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtMmHZRp5Jn/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686163967}]},
#   {'title': 'realkingbuzzo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtK2PftKaTz/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686109843}]},
#   {'title': 'krk_ryden',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtKxLcmPIbm/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686107864}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtKX_niOiEp/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686083123}]},
#   {'title': 'natalieknepp',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtKSx9EAHw7/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686081307}]},
#   {'title': 'heller3678',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtKNJkAuNFn/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686079421}]},
#   {'title': 'greasytrucker',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtJ2idIMDIw/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686067088}]},
#   {'title': 'monikajata',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtJtog_N5r-/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686061039}]},
#   {'title': 'heller3678',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtIAxHdMo-q/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1686004408}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CtHHycHPgIR/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685979145}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtG7bwzLMeF/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685967745}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtEzQdJOH1O/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685896675}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtDWaLjrBiG/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685849555}]},
#   {'title': 'maumausavannahcat',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtDQvPJRhwp/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685846780}]},
#   {'title': 'inferiorbrainpower',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtCMeSjunsP/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685810746}]},
#   {'title': 'melvinsdotcom',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtCO5oEO5mu/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685810733}]},
#   {'title': 'toddcamp',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CtAPJZHLg5E/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685744863}]},
#   {'title': 'deathatthechapel',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cs97O3rMmt-/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685733126}]},
#   {'title': 'sanspoint_',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cs_6pj_ujgH/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685733059}]},
#   {'title': 'alternativetentacles',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cs_ZWbDrDch/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685718194}]},
#   {'title': 'josh2hager',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cs99iX6s_H2/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685667645}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cs94BoyILw_/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685665142}]},
#   {'title': 'sanspoint_',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cs9rwTSSZFg/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685657140}]},
#   {'title': 'dasharez0neadmin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cs9dXauOp7t/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685651839}]},
#   {'title': 'obviousplant',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cs9HQOJx3KA/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685651809}]},
#   {'title': 'grimes',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CsrAyFIJuxE/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1685651032}]},
# ...
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668303988}]},
#   {'title': 'plasticdeervintage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ck3g7WQOjO5/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668271560}]},
#   {'title': 'american_daydream_miscellanea',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ck1WC8GODDN/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668228127}]},
#   {'title': 'alex2timezz',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ck2MdBJtURG/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668227865}]},
#   {'title': 'martiancolors',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ck109xlv_lz/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668218760}]},
#   {'title': 'davide.adler',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Ck1oSGJL-_g/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668207217}]},
#   {'title': 'dasharez0neadmin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cky1vtJOYoE/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668113867}]},
#   {'title': 'junko_mizuno_art',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CkyGxympHMs/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668093849}]},
#   {'title': 'hallmanscience',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkwxXQIuk2W/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668043999}]},
#   {'title': 'spudbyro',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ckvw_piOfVg/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668011893}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkvsDOQOS2V/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1668011860}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Cks3pN8Puz3/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667914490}]},
#   {'title': 'vincentdavidosborn',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ckre4R_L7aY/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667872266}]},
#   {'title': 'dasharez0neadmin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkqyJp9O7k7/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667846613}]},
#   {'title': 'elijahtapp',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ckqgs1eOw1t/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667841001}]},
#   {'title': 'evolvedspudboy',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkmplkpjeHD/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667705228}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ckl8eJdyCZG/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667687726}]},
#   {'title': 'martiancolors',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Ckj4tt0pw9y/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667612602}]},
#   {'title': 'may4taskforce',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkdqMktuVqa/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667405032}]},
#   {'title': 'thevaultoftheatomicspaceage',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkX04QENbtI/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667310009}]},
#   {'title': 'bjork',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkZtYUatLqB/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667271005}]},
#   {'title': 'gerald_casale',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkZqWsCpg12/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667269948}]},
#   {'title': 'alex2timezz',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkZgEdBtsOG/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667269929}]},
#   {'title': 'lcro.wd',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkZIf_UJAUS/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667251108}]},
#   {'title': 'lcro.wd',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkZIvX2JqrO/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667251088}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CkYX9svpgYV/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667227674}]},
#   {'title': 'joanng___',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkYJdDEOVOQ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667217690}]},
#   {'title': 'jello_biafra_gsm',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkXMVz6II47/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667217681}]},
#   {'title': 'alternativetentacles',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkW5r2pPkvU/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667176573}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CkUVUtpDABI/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667097976}]},
#   {'title': 'shelbsterina',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CkUjxKpJz1k/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667097918}]},
#   {'title': 'nutramusic',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkT4jKByJfg/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667078173}]},
#   {'title': 'martiancolors',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkT9iu4SQmu/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667078145}]},
#   {'title': 'sunfever.bengals',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkT08oQS-a2/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667073929}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkTP4yUuufK/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667056195}]},
#   {'title': 'darrinzwengel',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkSTnauMWjf/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667045505}]},
#   {'title': 'fightmilkband',
#    'string_list_data': [{'href': 'https://www.instagram.com/tv/CkRsORXj02J/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1667006898}]},
#   {'title': 'joanng___',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkRdARvOz4B/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666993744}]},
#   {'title': 'catatonicyouth',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkQw78cyipj/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666975371}]},
#   {'title': 'martiancolors',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkO4U-ESnkH/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666910241}]},
#   {'title': 'renprovo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkOQDoML25_/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666885832}]},
#   {'title': 'robinreneemusic',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkN2pgBuFi7/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666873204}]},
#   {'title': 'joanng___',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkNcZ1UuRB0/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666873125}]},
#   {'title': 'theonion',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkMVA92OKhb/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666841183}]},
#   {'title': 'martiancolors',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkMW7HIyT_b/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666830998}]},
#   {'title': 'masaninegloria',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkI_-MkujFg/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666713340}]},
#   {'title': 'winnerjeff',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkIzP0DO9gx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666702838}]},
#   {'title': 'krk_ryden',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkIATabuEGQ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666696645}]},
#   {'title': 'hallmanscience',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkHnEVFOYJT/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666666328}]},
#   {'title': 'joanng___',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkGM02yuR4p/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666617936}]},
#   {'title': 'martiancolors',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkEgz1iyasS/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666559087}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CkEHqHKJw51/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666550862}]},
#   {'title': 'gerald_casale',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CkEC2UephRe/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666545728}]},
#   {'title': 'rodrooter',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CkD9vWgpgg-/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666542362}]},
#   {'title': 'lisad00p',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkDu-VKtHGk/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666534356}]},
#   {'title': 'mondoobscurobooks',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkClQeUuyZD/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666494107}]},
#   {'title': 'gerald_casale',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CkB2L7gvPir/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666470305}]},
#   {'title': 'darrinzwengel',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CkBMlRmjaZ2/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666448996}]},
#   {'title': 'dasharez0neadmin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj_trAPNPct/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666400357}]},
#   {'title': 'kentstatehonorscollege',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj-x7I3ORmn/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666370760}]},
#   {'title': 'darrinzwengel',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj910YSu1yS/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666353383}]},
#   {'title': 'devomonkie',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj80CoOSsRD/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666304315}]},
#   {'title': 'clubdevo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj5-iZxv39e/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666208692}]},
#   {'title': 'malcolmtent2048oldmantent',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj5t9IPrpl_/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666201585}]},
#   {'title': 'melt_banana',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj5e2z_uTl-/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666192774}]},
#   {'title': 'bobbiewhitaker',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj3onjayA_D/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666127178}]},
#   {'title': 'renprovo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj1k29HLbNx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666061916}]},
#   {'title': 'malcolmtent2048oldmantent',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Cj1RDbTgd8M/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666052575}]},
#   {'title': 'collectedsearching',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj1C4LLOIOK/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666040874}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/Cj0ukugMrNA/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666030148}]},
#   {'title': 'melt_banana',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjyygekJtf2/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666028512}]},
#   {'title': 'renprovo',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cj0UiTBrGAX/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666015811}]},
#   {'title': 'art4mstudio',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjzH7M6omKR/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1666008031}]},
#   {'title': 'cumgirl8',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjyHYHDub3Q/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665941818}]},
#   {'title': 'maumausavannahcat',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjyHsGOp0RJ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665941696}]},
#   {'title': 'al_mothersbaugh',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cjx-Y6ROCmR/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665937905}]},
#   {'title': 'joanng___',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjwX5HbMMo0/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665885737}]},
#   {'title': 'maumausavannahcat',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cjv1Fd3P_Vb/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665865124}]},
#   {'title': 'joanng___',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cjvye30uvmL/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665865121}]},
#   {'title': 'shoestringrecordsandbooks',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjvbfrQOUTV/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665852828}]},
#   {'title': 'msmollyharvey',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjvWSh4uqAy/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665850445}]},
#   {'title': 'krk_ryden',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjujPomOT5p/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665826486}]},
#   {'title': 'victoria.dawn.03',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cjt0uRzJYkx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665801726}]},
#   {'title': 'catatonicyouths',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CjtVtYmJrkc/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665785482}]},
#   {'title': 'kentstate_sds',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cjs87f9A0OM/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665768682}]},
#   {'title': 'american_daydream_miscellanea',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjscanquPnx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665757532}]},
#   {'title': 'breedingcastle',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CcA-by1sPl2/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665635545}]},
#   {'title': 'dasharez0neadmin',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjoB-d2OSDE/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665611372}]},
#   {'title': 'collectedsearching',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cjn-zquO-Xc/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665611344}]},
#   {'title': 'alternativetentacles',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjmTbLHLWOq/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665545405}]},
#   {'title': 'robinreneemusic',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Cjlp40jujnx/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665523609}]},
#   {'title': 'melt_banana',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjlQjEYOboU/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665519166}]},
#   {'title': 'joanng___',
#    'string_list_data': [{'href': 'https://www.instagram.com/p/CjlaIr-O7jF/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665519157}]},
#   {'title': 'monsieurherr',
#    'string_list_data': [{'href': 'https://www.instagram.com/reel/CjjLNjkjY5S/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1665442928}]},
#   ...]}

# %% [markdown]
# Now we know where the timestamp values, which is what we want to access for this study, are located within the data structure. From this we can then isolate out these timestamps.

# %% [markdown]
# First we load up the 'likes_media_likes' data so we can access the values within.

# %%
likes_data['likes_media_likes'][0]
# Out:
# {'title': 'fruits_magazine_archives',
#  'string_list_data': [{'href': 'https://www.instagram.com/p/B4OAKpdlsBm/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1572391466}]}

# %% [markdown]
# Then we access 'string_list_data', which the timestamp data is located within.

# %%
likes_data['likes_media_likes'][0]['string_list_data'][0]
# Out:
# {'href': 'https://www.instagram.com/p/B4OAKpdlsBm/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1572391466}

# %% [markdown]
# Then we access the 'timestamp' values from having access to 'string_list_data'.

# %%
likes_data['likes_media_likes'][0]['string_list_data'][0]['timestamp']
# Out:
# 1572391466

# %% [markdown]
# Now that we know where the timestamp data is located, we can convert the likes data into a dataframe to visualize the data using access to the overarching 'likes_media_likes' as the jumping-off point.

# %%
likes_frame = pd.DataFrame(likes_data['likes_media_likes'])

# %% [markdown]
# We can add additional columns and visually sort our data to make it easier to digest using this frame. The syntax "['string_list_data'][0]['timestamp']" lets us navigate to the timestamp value from 'likes_media_likes'. We can make a new column from this syntax by first generating a list for the data we want in this new column.

# %%
data_list = [x['string_list_data'][0]['timestamp'] for x in likes_data['likes_media_likes']]

# %% [markdown]
# This is what the list of timestamps looks like:

# %%
data_list[0:10]
# Out:
# [1572391466,
#  1572383890,
#  1572348184,
#  1572311081,
#  1572283094,
#  1572283065,
#  1572277593,
#  1572277582,
#  1572227450,
#  1572227429]

# %% [markdown]
# Now we can make a new column in our dataframe from this list using this syntax and look at the frame itself.

# %%
likes_frame['timestamp'] = data_list

# %%
likes_frame
# Out:
#                          title  \
# 0     fruits_magazine_archives
# 1                michaelpilmer
# 2                   j0cko_h0mo
# 3     fruits_magazine_archives
# 4                   joshfreese
# ...                        ...
# 5916                  neozeiss
# 5917                 boojiboy_
# 5918             michaelpilmer
# 5919  fruits_magazine_archives
# 5920                  ropesnek
#
#                                        string_list_data   timestamp
# 0     [{'href': 'https://www.instagram.com/p/B4OAKpd...  1572391466
# 1     [{'href': 'https://www.instagram.com/p/B4NwMhl...  1572383890
# 2     [{'href': 'https://www.instagram.com/p/B4MOhGQ...  1572348184
# 3     [{'href': 'https://www.instagram.com/p/B4LhueT...  1572311081
# 4     [{'href': 'https://www.instagram.com/p/B4Kw13L...  1572283094
# ...                                                 ...         ...
# 5916  [{'href': 'https://www.instagram.com/p/B4Svtt0...  1572562649
# 5917  [{'href': 'https://www.instagram.com/p/B4SkjNU...  1572562641
# 5918  [{'href': 'https://www.instagram.com/p/B4SrWyr...  1572562637
# 5919  [{'href': 'https://www.instagram.com/p/B4QjXzY...  1572510700
# 5920  [{'href': 'https://www.instagram.com/p/B4OrN1t...  1572426708
#
# [5921 rows x 3 columns]

# %% [markdown]
# We want to analyze like counts by account. Let's group our frame by the names of the Instagram accounts, represented by the 'title' value, and examine it.

# %%
grouped_frame = likes_frame.groupby('title').count()
grouped_frame
# Out:
#                      string_list_data  timestamp
# title
# 123pingu                            1          1
# 2000s.internet                      1          1
# 2008_hyundai_sonata                 1          1
# 3chordpolitics                      1          1
# 3oclockrock_la                      1          1
# ...                               ...        ...
# zoomtecheurope                      1          1
# zorakfanclub                        1          1
# zuggyandkathy                       8          8
# zuorio                              1          1
# zyracthefool                        1          1
#
# [638 rows x 2 columns]

# %% [markdown]
# From this grouped frame, we can sort the values in descending order and use the head to get a top-however many values we want to analyze (the top twenty was chosen to be less narrow than just ten, but not excessive).
#
# This is our final data table:

# %%
grouped_frame.sort_values('timestamp', ascending = False).head(20)
# Out:
#                           string_list_data  timestamp
# title
# krk_ryden                              208        208
# clubdevo                               197        197
# darrinzwengel                          169        169
# michaelpilmer                          136        136
# martiancolors                          136        136
# robalster1                             107        107
# joshfreese                             103        103
# winnerjeff                             102        102
# msmollyharvey                          101        101
# theonion                               100        100
# evolvedspudboy                          96         96
# nightflightofficial                     91         91
# renprovo                                91         91
# neozeiss                                84         84
# theofficialresidents                    78         78
# gerald_casale                           78         78
# josh2hager                              78         78
# everythingisterrible666                 78         78
# criterioncollection                     75         75
# counterfeitmoneymachine_                74         74

# %% [markdown]
# Now we have the top twenty accounts sorted by number of likes given by my account.

# %% [markdown]
# <h3>Data analysis</h3>
#
# <p>Upon generating my list, I realized that the original intention behind my initial hypothesis was somewhat forgetful. When I drafted my hypothesis, I did not consider the nuances between average Joes using Instagram and popular, more public figures using the platform as an extention of whatever work they are trying to promote. I may consider myself immune to "influencer" culture, but I'm still following people with some degree of a following on Instagram and using Instagram in general, so I guess I'm still playing into it. To take this into account, I split the "average Joes" and "well known people" categorizations of "individuals" into <b>individuals</b> and <b>professional individuals</b> respectively to coincide with the <b>organizations</b> category, as opposed to just individuals and organizations as originally defined in the hypothesis, which turned out to be too vague.
#
# <ol>
#     <li>An artist who I like. <b>Professional individual</b>.</li>
#     <li>A band I like. <b>Organization</b>.</li>
#     <li>My dad! <b>Individual</b>.</li>
#     <li>Someone I don't talk to anymore, but I was friends with him. <b>Individual</b>.</li>
#     <li>A friend of mine. <b>Individual</b>.</li>
#     <li>Also a friend. <b>Individual</b>.</li>
#     <li>A famous drummer. <b>Professional individual</b>.</li>
#     <li>A friend. <b>Individual</b>.</li>
#     <li>A musician I used to listen to. <b>Professional individual</b>.</li>
#     <li>Satirical news. <b>Organization</b>.</li>
#     <li>A friend. <b>Individual</b>.</li>
#     <li>A streaming service i used to use. <b>Organization</b>.</li>
#     <li>A friend. <b>Individual</b>.</li>
#     <li>A friend. <b>Individual</b>.</li>
#     <li>A band I used to like. <b>Organization</b>.</li>
#     <li>An musician I like. <b>Professional individual</b>.</li>
#     <li>An musician I like. <b>Professional individual</b>.</li>
#     <li>Funny edited videos. <b>Organization</b>.</li>
#     <li>The creators behind the Criterion DVDs. <b>Organization</b>.</li>
#     <li>A friend. <b>Individual</b>.</li>
# </ol>
#
# <p>Out of the ten accounts with the most amount of liked posts,</p>
# <ul>
#     <li><b>Nine</b> of the accounts represented <b>individuals</b>.</li>
#     <li><b>Six</b> of the accounts represented <b>organizations</b>.</li>
#     <li><b>Five</b> of the accounts represented <b>professional individuals</b>.</li>
# </ul>
#
# <p>Hence, the data proved the hypothesis of a positive relationship between the liked posts and their posting by an individual, not an organization, to be <b>correct</b>.
#
# <p>However, there were further nuances to this analysis than I expected, considering the distinction between non-professional and professional individuals. On top of this, three of the "professional individuals" featured in my data I've actually met and consider myself an acquaintance of. I went into this data report thinking that the data would show curated pages by bands and entertainment pages versus friends not chained to any sort of social rep just posting things that happen in their lives. It turns out that, in my case, the lines are a little blurrier! An analysis like this could take a vast amount of different approaches depending on how one classified the accounts being analyzed.</p>
#
# <p>Such data could also be used to draw wider conclusions about how people use Instagram than just focusing on one user's liking habits. An interesting perspective to take using this data could be to examine whether or not accounts with many "likes" are specifically labeled as "professional" accounts or not. Many accounts run by individuals are registered as "professional" accounts with a tagline on their profile for one's occupation, some of which don't even coincide with one's line of work for humor or "aesthetic" purposes. (I am not immune to this; my account claims I am a "scientist" just because I think it's cheeky.) We could draw parallels between the likes granted to average Joe individuals and individuals who deem themselves relevant enough in some way to click the button for the professional account for added profile oomph.</p>
#
# <p>While the data here is useful, it seems that most of the analysis comes from examining the accounts themselves for further information since the data does not contain any of the intricacies of these accounts and is solely focused on one user's "like" data, as opposed to anything deeper. It is up to human analysis and inference to come to a meaningful conclusion, which is a slight limitation.</p>
