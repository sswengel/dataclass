# %% [markdown]
# <h1>Final Project Preliminary - Data in Hand</h1>
#
# <h4>Sophia Swengel</h4>
#
# November 28, 2023
#
# <hr/>
#
# <p>These are the data tables, sourced from the <a href="https://highered.ohio.gov/data-reports/key-topic-areas/dr-degrees/data-reports-degrees">Ohio Department of Higher Education website</a>, that I will be using in my final project analysis.</p>

# %%
import pandas as pd

# %%
df_2002_2011 = pd.read_csv("20022011.csv")
df_2002_2011.head()
# Out:
#                Sector                Institution    Discipline Area  \
# 0  Community Colleges  Belmont Technical College  Arts & Humanities
# 1  Community Colleges  Belmont Technical College           Business
# 2  Community Colleges  Belmont Technical College           Business
# 3  Community Colleges  Belmont Technical College           Business
# 4  Community Colleges  Belmont Technical College           Business
#
#                     Subject Field   Level of Degree or Certificate  \
# 0     Liberal and General Studies                 Associate Degree
# 1                      Accounting                 Associate Degree
# 2                      Accounting         Less than One-Year Award
# 3                      Accounting  One to less than Two-Year Award
# 4  Administrative and Secretarial                 Associate Degree
#
#    Awards in FY 2002  Awards in FY 2003  Awards in FY 2004  Awards in FY 2005  \
# ...

# %% [markdown]
# <p>The above data table is the awards of degrees from Ohio universities from 2002 to 2011.</p>

# %%
df_2012_2023 = pd.read_csv("20122023.csv")
df_2012_2023.head()
# Out:
# /var/folders/dz/bmyfzjwj11n3v1wj7dck4frm0000gn/T/ipykernel_51311/159119792.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2012_2023 = pd.read_csv("20122023.csv")
#                      sector               campus awlevel  UNITID Inst_code  \
# 0  University Main Campuses  University of Akron       7  200800      AKRN
# 1  University Main Campuses  University of Akron       5  200800      AKRN
# 2  University Main Campuses  University of Akron       7  200800      AKRN
# 3  University Main Campuses  University of Akron       5  200800      AKRN
# 4  University Main Campuses  University of Akron       7  200800      AKRN
#
#                                      SUBJECT_TITLE  \
# 0                        Geophysics and Seismology
# 1                                        Geography
# 2                             Keyboard Instruments
# 3                                  Voice and Opera
# ...

# %% [markdown]
# <p>The above data table is the awards of degrees from Ohio universities from 2012 to 2023.</p>

# %% [markdown]
# <p>These two data tables can be wrangled to examine the awarding of bachelors degrees in history by Kent State University specifically. While both tables have individual columns for important values such as specific campus, the degree subject area and field, and the degree level, the 2002-2011 data table has one column per year to represent the amount of degrees awarded per year, while the 2012-2023 page has just one column with the entry for each row being the specific year the award was granted and another column for the amount granted that year. Hence, these tables will need some merging and wrangling of columns for clarity of analysis.</p>
